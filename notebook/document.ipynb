# %% [markdown]
# ### Data Ingestion

# %% [markdown]
# ### document data structure

# %%
from langchain_core.documents import Document
# Out:
# /Users/saikumarpadamati/Desktop/RAG/.venv/lib/python3.14/site-packages/langchain_core/_api/deprecation.py:25: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1

# %%
doc=Document(
    page_content=" this is the main text i am using in RAG",
    metadata={
        "source" : "example.txt",
        "pages" : 1,
        "author" : "Saikumar",
        "date_created" : "2026-03-25"
    }
)
doc
# Out:
# Document(metadata={'source': 'example.txt', 'pages': 1, 'author': 'Saikumar', 'date_created': '2026-03-25'}, page_content=' this is the main text i am using in RAG')

# %%
### create simple txt file

import os
os.makedirs("../data/text_files", exist_ok=True)

# %%
sample_texts={
    "../data/text_files/python_intro.txt":"""Python Programming Introduction

Python is a high-level, interpreted programming language known for its simplicity and readability.
Created by Guido van Rossum and first released in 1991, Python has become one of the most popular
programming languages in the world.

Key Features:
- Easy to learn and use
- Extensive standard library
- Cross-platform compatibility
- Strong community support

Python is widely used in web development, data science, artificial intelligence, and automation.""",
    
    "../data/text_files/machine_learning.txt": """Machine Learning Basics

Machine learning is a subset of artificial intelligence that enables systems to learn and improve
from experience without being explicitly programmed. It focuses on developing computer programs
that can access data and use it to learn for themselves.

Types of Machine Learning:
1. Supervised Learning: Learning with labeled data
2. Unsupervised Learning: Finding patterns in unlabeled data
3. Reinforcement Learning: Learning through rewards and penalties

Applications include image recognition, speech processing, and recommendation systems
    
    
    """

}

for filepath,content in sample_texts.items():
    with open(filepath,'w',encoding="utf-8") as f:
        f.write(content)

print("✅ Sample text files created!")
# Out:
# ✅ Sample text files created!

# %%
### TextLoader
###from langchain.document_loaders import TextLoader

from langchain_community.document_loaders import TextLoader

loader=TextLoader("../data/text_files/python_intro.txt",encoding="utf-8")
document=loader.load()
print(document)
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.')]

# %%
### Directory Loader
from langchain_community.document_loaders import DirectoryLoader

## load all the text files from the directory
dir_loader=DirectoryLoader(
    "../data/text_files",
    glob="**/*.txt", ## Pattern to match files  
    loader_cls= TextLoader, ##loader class to use
    loader_kwargs={'encoding': 'utf-8'},
    show_progress=False

)

documents=dir_loader.load()
documents
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.'),
#  Document(metadata={'source': '../data/text_files/machine_learning.txt'}, page_content='Machine Learning Basics\n\nMachine learning is a subset of artificial intelligence that enables systems to learn and improve\nfrom experience without being explicitly programmed. It focuses on developing computer programs\nthat can access data and use it to learn for themselves.\n\nTypes of Machine Learning:\n1. Supervised Learning: Learning with labeled data\n2. Unsupervised Learning: Finding patterns in unlabeled data\n3. Reinforcement Learning: Learning through rewards and penalties\n\nApplications include image recognition, speech processing, and recommendation systems\n\n\n    ')]

# %%
from langchain_community.document_loaders import PyPDFLoader, PyMuPDFLoader

## load all the text files from the directory
dir_loader=DirectoryLoader(
    "../data/pdf",
    glob="**/*.pdf", ## Pattern to match files  
    loader_cls= PyMuPDFLoader, ##loader class to use
    show_progress=False

)

pdf_documents=dir_loader.load()
pdf_documents
# Out:
# [Document(metadata={'producer': 'PDF-XChange Printer V6 (6.0 build 317.1) [Windows 10 Enterprise x64 (Build 19045)]', 'creator': '', 'creationdate': '2024-11-25T19:56:12-06:00', 'source': '../data/pdf/Work Opportunity Tax Credit (WOTC).pdf', 'file_path': '../data/pdf/Work Opportunity Tax Credit (WOTC).pdf', 'total_pages': 1, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': "D:20241125195612-06'00'", 'page': 0}, page_content='Work Opportunity Tax Credits – KBR, Inc.\nKBR, Inc. participates in the Work Opportunity Tax Credit (WOTC) program, which ADP\nadministers on behalf of the company. Please follow the steps listed below to screen for\nthe WOTC program.  We appreciate your cooperation.\nApplicant Instructions\n•\nOpen https://tcs.adp.com/kbrinc  or scan the QR code below.\n**Note: If using a shared screening device, ensure the device does not have an\nautofill/auto complete function enabled\n•\nPlease answer each question to complete the voluntary screening.\n•\nEligible applicants will be asked to Electronically Sign and click Submit to\ncomplete the screening.\n•\nIneligible applicants will be asked to click Submit to finish the screening. You\nwill not be asked to electronically sign.\n**ADP will contact WOTC-eligible new hires via email or text to request proof of age or\naddress documentation, when needed.\n**If you are unable to screen via the Web Link please contact ADP at 1-800-237-3279 (1-\n800-ADP-EASY) available 6am-11 pm ET, 6 days a week and 7am-7pm Sunday, and enter\ncompany code shown below to screen for Tax Credits.\nIVR CODE: 196262'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-01-15T22:01:41+00:00', 'source': '../data/pdf/saikumar_resume_java (6).pdf', 'file_path': '../data/pdf/saikumar_resume_java (6).pdf', 'total_pages': 2, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-01-15T22:01:41+00:00', 'trapped': '', 'modDate': 'D:20260115220141Z', 'creationDate': 'D:20260115220141Z', 'page': 0}, page_content='Sai Kumar Padamati\nÆ 3527097523 | [ saikumarpadamati0313@gmail.com | ½ Normal, Illinois | \x87 GitHub | Portfolio | ° LinkedIn\nEducation\nUniversity of Florida\nGainesville, Florida\nMaster of Science in Computer Science; GPA: 3.7/4.0\nAug 2022 – May 2024\nJNTU College of Engineering Hyderabad\nTelangana, India\nBachelor of Technology in Electronics & Communication Engineering; GPA: 3.9/4.0\nAug 2015 – May 2019\nSkills\nProgramming: Java, JavaScript(Reactjs, Nodejs), Python, Go\nTechnologies: REST APIs, GrapgQl, Spring Boot, Hibernate, nodeJs, ExpressJs, HTML, TailwindCSS, ReactJs,\nRedux, JUnit, Mockito, Webpack, OpenAPI/Swagger, Kafka, Apache Jmeter, Microservices.\nDevops/Cloud: Linux, Docker, Kubernetes, Helm charts, AWS, SonarQube, Microservices, Prometheus, Grafana.\nDeveloper tools: Git, Github, Debugging, VS Code, IntelliJ, Eclipse, Postman, Maven, Tomcat, Jira.\nDatabases: MySQL, PostgreSQL, DBeaver, NoSQL(MongoDB), Elasticsearch ELK stack, Redis.\nWork Experience\nKGS Technology Group\nRemote\nSoftware Engineer\nAug 2025 – present\n• Engineered enterprise applications using Java and springboot(microservices) to optimize large-scale logistics\nworkflows, resulting in a 20% improvement in operational reliability.\n• Developed full-stack solutions with React.js and Nodejs (full-stack development) to streamline user management,\nresulting in a 35% decrease in onboarding time.\n• Deployed modular microservices on AWS (EC2, ECS, S3) using AWS Lambda (cloud architecture) to reduce\noperational costs by 30% and improve system reliability.\n• Implemented MVC best practices in spring framework (software architecture) to promote separation of\nconcerns, resulting in a 40% faster development cycle and simpler maintenance.\nCommunity Dreams\nRemote\nVolunteer Software Engineer\nSep 2024 – July 2025\n• Developed RESTful APIs for CRUD operations on Employees, Attendance,Task Records and leave management for\nHR management System.Implemented business logic for time tracking and leave approval processes using Spring\nSecurity for authentication and authorization.\n• Integrated SQL and NoSQL databases (MySQL, MongoDB) (database management) to handle high-volume\ntransactions, resulting in sub-second query responses for 95% of requests.\nBrillio Technologies\nHyderabad, India\nSenior Software Engineer\nFeb 2022 – Aug 2022\n• Implemented API load and performance testing strategies using tools like Apache JMeter and Gatling to\nsimulate real-world traffic, analyze system scalability, and optimize backend performance .\n• Designed end-to-end CI/CD pipelines using Jenkins, Agile practices, and Terraform to automate infrastructure\nprovisioning (GCP) and GitOps-driven deployments (Flux), reducing deployment cycles by 40% and errors by 50%\n• Achieved an average of 98% test coverage across microservices by leveraging Test-Driven Development (TDD)\nmethodology, ensuring robust and reliable code quality.\n• Utilized Docker to create and manage containerized applications, enabling efficient development and deployments.\nWipro Technologies\nHyderabad, India\nProject Engineer\nJun 2019 – Feb 2022\n• Developed and enhanced REST APIs using Java, Spring Boot, Node.js, Express.js, JavaScript, and Sequelize ORM\nto facilitate RDBMS CRUD operations as full stack developer\n• Integrated services using RestTemplate and GSON library.Implemented new features according to user stories\nand provided support and bug fixes throughout the software development lifecycle (SDLC).\n• I ...
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-01-15T22:01:41+00:00', 'source': '../data/pdf/saikumar_resume_java (6).pdf', 'file_path': '../data/pdf/saikumar_resume_java (6).pdf', 'total_pages': 2, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-01-15T22:01:41+00:00', 'trapped': '', 'modDate': 'D:20260115220141Z', 'creationDate': 'D:20260115220141Z', 'page': 1}, page_content='Projects\nStock Portfolio Analyser\nClick here\n• Designed and executed a visual stock portfolio analyser from scratch using Java 8, SpringBoot REST API,\nGradle. Created the core logic using DesignPatterns, refactored the code to add support for multiple stock\nservices.Improved the application stability and performance by 60% by using multi-threading.\nEvent Driven Microservices — Spring Boot, Kafka, Elastic Search, Kafka Streams\nClick here\n• Used an elevated developer account on Twitter and integrated the twitter4j API to filter tweets based on specific\nkeywords, storing them in a Kafka event store.\n• Developed REST APIs along with Open API documentation, to fetch and validate data from Elasticsearch,\nenabling robust data retrieval based on API requests via Postman.\n• Implemented CQRS pattern in microservices to independently develop, deploy, and scale services, leveraging\nDocker images for Kafka and Elasticsearch clusters.'),
#  Document(metadata={'producer': '', 'creator': 'Microsoft Word', 'creationdate': '2023-03-02T16:17:37+00:00', 'source': '../data/pdf/paper-drieve.pdf', 'file_path': '../data/pdf/paper-drieve.pdf', 'total_pages': 6, 'format': 'PDF 1.7', 'title': '1', 'author': 'Administrator', 'subject': '', 'keywords': '', 'moddate': '2023-03-02T16:17:37+00:00', 'trapped': '', 'modDate': "D:20230302161737+00'00'", 'creationDate': "D:20230302161737+00'00'", 'page': 0}, page_content='Driving Written Test : \n \n1. When you come to a stop sign, you must stop your vehicle : \n◼ As close to the stop sign as possible. \n◼ At place near the intersection providing you come to a complete stop. \n◼ At marked stop line, before entering the crosswalk, or before entering the \nintersection if there is no crosswalk. \n \n \n2. When headlight are required, they should be dimmed at least 500 feet before \nmeeting and 300 feet before overtaking another vehicle. \n◼ True  \n◼ False \n3. When driving along the highway and the front wheel of your vehicle runs off the \npavement, you should : \n◼ Quickly swing back onto the pavement at your normal speed. \n◼ Grasp the steering wheel tightly & take your foot off the accelerator. \n◼ Apply the brakes immediately and swing the back onto the pavement \nquickly. \n◼  \n4. Most rear end collisions are caused by : \n◼ Dangerous road conditions. \n◼ The vehicle in front stopping too fast. \n◼ The vehicle in back following too closely. \n5. Which of the following in the single greatest factor in fatal motor vehicle \naccidents ? \n◼ Alcohol  \n◼ Mechanical problems \n◼ Bad weather conditions \n◼ Bad road conditions \n6. When a right turn against a red signal light is allowed, the proper way to make the \nturn is to : \n◼ Stop. Give right-of-way to any persons or vehicles within the intersection, \nthen cautiously make the turn. \n◼ Turn quickly to get out of the way of other vehicles. \n◼ Stop. Sound your horn to warn other traffic, then make your turn. \n7. After consuming alcohol, time is only effective way to remove alcohol from the \nbody. \n◼ True  \n◼ False \n8. When passing another vehicle, you should not cut back into the right lane until \nyou can see the vehicle that you just passed in your rearview mirror. \n◼ True  \n◼ False'),
#  Document(metadata={'producer': '', 'creator': 'Microsoft Word', 'creationdate': '2023-03-02T16:17:37+00:00', 'source': '../data/pdf/paper-drieve.pdf', 'file_path': '../data/pdf/paper-drieve.pdf', 'total_pages': 6, 'format': 'PDF 1.7', 'title': '1', 'author': 'Administrator', 'subject': '', 'keywords': '', 'moddate': '2023-03-02T16:17:37+00:00', 'trapped': '', 'modDate': "D:20230302161737+00'00'", 'creationDate': "D:20230302161737+00'00'", 'page': 1}, page_content='9. When a school bus is stopped on two-lane highway and its red warning lights are \nflashing and its stop signal arm is extended, you just : \n◼ Slow down, sound your horn and pass the bus with caution. \n◼ Stop your vehicle before reaching the bus. \n◼ Pass the bus on the left if there are no vehicles approaching from the \nopposite direction. \n10. A person may never drive a motor vehicle (even if borrowed or rented for a short \nperiod of time) unless the operator holds a valid drivers license which is properly \nclassified for that kind and type of vehicles. \n◼ True \n◼ False \n11. When there are flashing signals at a railroad crossing and the clears the crossing, \nhow soon you should proceed ? \n◼ Follow the vehicle ahead of you. \n◼ After you check to make sure another train is not approaching on another \ntrack. \n◼ Just as soon as the train clears the crossing. \n \n12. When a two-lane pavement is marked with a single, solid yellow line on your side \nof the center line : \n◼ Construction work is going on ahead, slow down. \n◼ You must not cross yellow line to pass another vehicle. \n◼ You must slow down and proceed with caution. \n13. Which of the following laws and safety rules apply to bicyclists ? \n◼ Bicyclists should travel in the opposite direction of other vehicles. \n◼ The safest hours for operation are during times of poor visibility. \n◼ Bicyclists are entitled to the same right-of-way as other vehicle. \n14. When asking a left or right turn in a business or residential district, a continuous \nsignal to turn must be given : \n◼ Not less than 100 feet before turning. \n◼ Only when vehicle are coming toward you. \n◼ At least 50 feet from the intersection. \n15. When an authorized emergency vehicle is using its siren and flashing lights \napproaches your vehicle, you should : \n◼ Increase your speed. \n◼ Continue at the same speed. \n◼ Pull over to the right hand edge of the highway and stop, if possible. \n16. If your vehicle starts to skid on water (hydroplane), you should : \n◼ Take your foot off the accelerator and let your vehicle slow down. \n◼ Turn your wheel slightly to the right and brake gently. \n◼ Turn your ignition off and coast to a stop.'),
#  Document(metadata={'producer': '', 'creator': 'Microsoft Word', 'creationdate': '2023-03-02T16:17:37+00:00', 'source': '../data/pdf/paper-drieve.pdf', 'file_path': '../data/pdf/paper-drieve.pdf', 'total_pages': 6, 'format': 'PDF 1.7', 'title': '1', 'author': 'Administrator', 'subject': '', 'keywords': '', 'moddate': '2023-03-02T16:17:37+00:00', 'trapped': '', 'modDate': "D:20230302161737+00'00'", 'creationDate': "D:20230302161737+00'00'", 'page': 2}, page_content='17. If you are convicted of passing a school bus that is receiving or discharging \npassengers. You may lose your drivers license for at least 30 days.(3 months) \n◼ True  \n◼ False \n18. The road surface of a bridge may be dangerous in winter because : \n◼ The bridge surface is warmer. \n◼ There may be ice on bridge even when other pavements are clear. \n◼ Neither of these. \n19. A flashing red traffic signal light a an intersection means: \n◼ An emergency vehicle is approaching from your rear. \n◼ You should be careful when going to the intersection. \n◼ Exactly the same thing as a stop sign. \n20. It is permissible for you to pass on the shoulder of the road. \n◼ True  \n◼ False \n21. When required to stop at railroad crossing, vehicle must stop, \n◼ within 25 feet, but not less than 15 ft from the nearest railroad crossing. \n◼ Within 50 feet, but not less than 15 feet from the nearest railroad crossing. \n◼ Within 75 feet, but not less than 25 feet from the nearest railroad crossing. \n◼ Within 100 feet, but not less than 50 feet from the nearest railroad \ncrossing. \n22. In order to reinstate full driving privileges after a DRIVING UNDER THE \nINFLUENCE (DUI) revocation, a person must: \n◼ carry high-risk auto insurance for three year. \n◼ Be approved for reinstatement by a Secretary of State Hearing Officer and \npay a $ 60 reinstatement fee. \n◼ Submit to a professional assessment of alcohol and/or drug use and attend \na remedial or rehabilitation program. \n◼ Wait for the one year. \n◼ All of the above. \n23. IT is unlawful for any person to leave the roadway and travel across private \nproperty to avoid an official control devices.  \n◼ True  \n◼ False \n24. When driving an a slippery road and the rear end of your vehicle starts to skid, \nyou should : \n◼ Apply brake gently  \n◼ Turn the front wheel in the direction of the skid. \n◼ Hold the wheel firmly  and steer straight ahead, braking gradually.'),
#  Document(metadata={'producer': '', 'creator': 'Microsoft Word', 'creationdate': '2023-03-02T16:17:37+00:00', 'source': '../data/pdf/paper-drieve.pdf', 'file_path': '../data/pdf/paper-drieve.pdf', 'total_pages': 6, 'format': 'PDF 1.7', 'title': '1', 'author': 'Administrator', 'subject': '', 'keywords': '', 'moddate': '2023-03-02T16:17:37+00:00', 'trapped': '', 'modDate': "D:20230302161737+00'00'", 'creationDate': "D:20230302161737+00'00'", 'page': 3}, page_content='25. When a traffic light shows both a red light and a green arrow in the direction you \nwish to turn, you : \n◼ Have the right-of-way over pedestrians in turning in the direction of the \narrow. \n◼ May proceed in the direction of arrow with caution. \n◼ Must stop and remain stop until the red light has changed. \n26. The 2-seacond Rule works like this when the vehicle ahead of you passes a fixed \nobject like a tree etc., if you begin counting “ One thousand one, One thousand \ntwo “ then if you reach the same tree before you have finished saying :one \nthousand two”, you are following too closely . \n◼ True \n◼ False \n27. Illinois law requires children under age 6 to be secured by a restraint system or \nseat belt when traveling in a motor vehicle: \n◼ In the front seat only. \n◼ Anywhere in the vehicle \n◼ In the back seat only \n◼ Never, this is not a law. \n28. A diver moving out of a alley, privet road, or driveway within an urban area must : \n◼ Sound your horn and exit quickly. \n◼ Stop only if there are vehicles coming down the street. \n◼ Stop before reaching the sidewalk and yield to pedestrians and vehicle \nbefore proceeding. \n29. If you most drive during the foggy weather, you should turn on the low-beam \nheadlight and : \n◼ flash your lights routinely.  \n◼ Keep your foot on the brake pedal so your tail lights will be seen more \neasily. \n◼ Drive at a speed that will allow you to stop within your field of vision. \n30. When approaching a blind pedestrian carrying  a white cane or accompanied by a \nguide bog: \n◼ you may pass of you slow down and sound the horn. \n◼ You must yield the right-of-way. \n◼ You may pass if there are no vehicles approaching from the opposite \ndirection. \n31. Motorcycles , though smaller & lighter in weight, have the same right-of-way \nprivileges as other vehicles, Special observance should be given to motorcyclists \nwhen they approach an intersection, a railroad crossing , bridge or when bad \nweather occurs. \n◼ True  \n◼ False.'),
#  Document(metadata={'producer': '', 'creator': 'Microsoft Word', 'creationdate': '2023-03-02T16:17:37+00:00', 'source': '../data/pdf/paper-drieve.pdf', 'file_path': '../data/pdf/paper-drieve.pdf', 'total_pages': 6, 'format': 'PDF 1.7', 'title': '1', 'author': 'Administrator', 'subject': '', 'keywords': '', 'moddate': '2023-03-02T16:17:37+00:00', 'trapped': '', 'modDate': "D:20230302161737+00'00'", 'creationDate': "D:20230302161737+00'00'", 'page': 4}, page_content='32. When you are driving and one of the tire has a blowout , you should : \n◼ Quickly steer onto the right shoulder. \n◼ Apply the brakes quickly to reduce speed. \n◼ Grip the steering wheel firmly, take your foot off the gas pedal, and let the \nvehicle slow down before you drive onto the shoulder. \n33. The driver and front seat passengers (age 6 and above) are required to wear seat \nsafety belts while riding in a motor vehicle on Illinois roadways. Vehicles are \nsubject to: \n◼ $75 fine plus court cost. \n◼ Suspension of their driver’s license. \n◼ A $25 fine plus court cost. \n◼ None of the above \n34. You are waiting at an intersection and the traffic signal light changes to green. \nYou may then go ahead : \n◼ When you think it is safe to do so. \n◼ After first yielding the right-of-way to any persons or vehicles which are \nwithin the intersection. \n◼ Immediately  \n35. A person who REFUSES to subject to a chemical test of his/her blood, breath of \nurine,for the purpose of determining the level of alcohol and/or drug contents : \n◼ Will receive a drivers license suspension for 12 months for second \noffender within 5 year period. \n◼ May have this used as evidence against his/her in court if charged with \nDRIVING UNDER THE INFLUNCE of alcohol and/or drugs. (DUI) \n◼ Will receive drivers license suspension for six months on first offence. \n◼ All of the above. \n36. Your driving privileges will be revoked in the State of Illinois if you are convicted \nof : \n◼ Drug racing . \n◼ Driving or being in actual physical control of a vehicle while under the \ninfluence of alcohol or other drugs (including prescription drugs which \nmay affect driving ability)and/or combinations, thereof. \n◼ Leaving the scene of an accident in which you are involved as a driver, if \nthe accident results in death or personal injury. \n◼ None of the above \n◼ All of the above.'),
#  Document(metadata={'producer': '', 'creator': 'Microsoft Word', 'creationdate': '2023-03-02T16:17:37+00:00', 'source': '../data/pdf/paper-drieve.pdf', 'file_path': '../data/pdf/paper-drieve.pdf', 'total_pages': 6, 'format': 'PDF 1.7', 'title': '1', 'author': 'Administrator', 'subject': '', 'keywords': '', 'moddate': '2023-03-02T16:17:37+00:00', 'trapped': '', 'modDate': "D:20230302161737+00'00'", 'creationDate': "D:20230302161737+00'00'", 'page': 5}, page_content='37. When approaching a railroad grade crossing which does not have any warning \nsystems (such as electric flashing lights or gates) you should : \n◼ continue at your normal speed. \n◼ Look, listen, slow down in case you have to stop, and proceed when safe \nto do so. \n◼ Increase Speed and cross tracks as quickly as possible. \n38. Unless posted otherwise, it is permissible for drivers on one-way street to turn left \non a red light into another one-way street that moves traffic to the left after \nmaking a proper stop and yielding to traffic or pedestrians within the intersection . \n◼ True  \n◼ False \n39. Motorcycles are entitled to use the fuel width of a traffic lane, the same as a \nvehicle. Therefore, when you are driving a vehicle and want to pass a motorcycle, \nyou should: \n◼ Follow the motorcycle without passing it. \n◼ Cautiously pass the motorcycle, sharing the same lane it is using. \n◼ Not to pass the motorcycle in the same lane that it is using, but change \nlanes and pass the way you would pass another vehicle.  \n40. Your driver license will be suspended if: after arrested for DRIVING UNDER \nTHE INFLUENCE of alcohol and/or drugs (DUI) \n◼ You take a chemical test (breath, blood or urine) and register an amount \nequal to or over the legal level intoxication(.10%) \n◼ You refuse to take a chemical test (breath, blood or urine).  \n◼ You take a chemical test and register a .04%.(provided your driving ability \nimpaired. \n◼ A and B are correct. \n◼ All of the above.')]
